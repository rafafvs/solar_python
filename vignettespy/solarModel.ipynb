# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.optimize import minimize_scalar
from sklearn.mixture import GaussianMixture

from solarrpy import seasonalClearsky
from solarrpy import seasonalModel
from solarrpy import ARMA_model    # ARMAModel
from solarrpy import sGARCH        # sGARCH
from solarrpy import solarMixture  # SolarMixture

# %%
import numpy as np
import pandas as pd

omega = 2 * np.pi / 365

# ── Raw data ──────────────────────────────────────────────────────────────
df = pd.read_csv("data/Bologna.csv")
df['date'] = pd.to_datetime(df['date'])

spec = {
    'target': 'GHI',
    'coords': {'lat': 44.4949, 'lon': 11.3426, 'alt': 71},
    'data': df
}

# ── Load saved clearsky + Yt results ──────────────────────────────────────
# Saved at end of notebook-seasonalClearsky.ipynb as:
# computed_values_df.to_csv('../results/TableA1_Ct_Yt.csv', index=False)
ct_df = pd.read_csv("results/TableA1_Ct_Yt.csv", parse_dates=['Year'])

print(ct_df.shape)
print(ct_df.columns.tolist())
display(ct_df.head(3))
# Out:
# (10, 19)
# ['Year', 'alpha', 'beta', 'delta0', 'delta1', 'delta2', 'delta3', 'delta0_err', 'delta1_err', 'delta2_err', 'delta3_err', 'a0', 'a1', 'a2', 'a0_err', 'a1_err', 'a2_err', 'Y_t', 'C_t']
#         Year     alpha      beta    delta0    delta1    delta2    delta3  \
# 0 2013-01-01  0.004111  0.917898 -1.171186  0.945920  0.011139  0.509035
# 1 2014-01-01  0.006516  0.915698 -1.081238  0.935924  0.025055  0.450303
# 2 2015-01-01  0.007020  0.915248 -1.311949  0.967261  0.000488  0.585260
#
#    delta0_err  delta1_err  delta2_err  delta3_err        a0        a1  \
# 0    0.319647    0.042880    0.031798    0.182858 -0.022142 -0.053265
# 1    0.302052    0.040519    0.030048    0.172792 -0.069200 -0.073676
# 2    0.285686    0.038324    0.028420    0.163429 -0.077484 -0.068034
#
#          a2    a0_err    a1_err    a2_err  \
# 0 -0.354409  0.011512  0.016285  0.016275
# 1 -0.395907  0.016755  0.023702  0.023688
# 2 -0.391266  0.015798  0.022348  0.022335
#
# ...
